# %% [markdown]
# # **Exception Handling**
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# -   Understand exceptions
# -   Handle the exceptions

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# -   What is an Exception?
# -   Exception Handling

# %% [markdown]
# * * *

# %% [markdown]
# ## What is an Exception?

# %% [markdown]
# In this section you will learn about what an exception is and see examples of them.

# %% [markdown]
# ### Definition

# %% [markdown]
# Una excepción es un error que ocurre durante la ejecución del código. Este error hace que el código genere una excepción y, si no está preparado para manejarlo, detendrá la ejecución del código.

# %% [markdown]
# ### Examples

# %% [markdown]
# Run each piece of code and observe the exception raised

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-9e1622b385b6> in <module>
# ----> 1 1/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# <code>ZeroDivisionError</code> occurs when you try to divide by zero.

# %%
y = a + 5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-6ddcec040107> in <module>
# ----> 1 y = a + 5
#
# NameError: name 'a' is not defined

# %% [markdown]
# <code>NameError</code> in this case means that you tried to use the variable a when it was not defined.

# %%
a = [1, 2, 3]
a[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-3f911ca4e3d3> in <module>
#       1 a = [1, 2, 3]
# ----> 2 a[10]
#
# IndexError: list index out of range

# %% [markdown]
# <code>IndexError</code> in this case occurs when you try to access data from a list using an index that does not exist for this list.

# %% [markdown]
# There are many more exceptions that are built into Python, here is a list of them [https://docs.python.org/3/library/exceptions.html](https://docs.python.org/3/library/exceptions.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork19487395-2021-01-01)

# %% [markdown]
# ## Exception Handling -> Manejo de excepciones

# %% [markdown]
# En esta sección aprenderá a manejar excepciones para realizar ciertas tareas y no detener la ejecución de su código.

# %% [markdown]
# ### Try Except

# %% [markdown]
# Un <code>try except</code> le permitirá ejecutar código que podría generar una excepción y, en el caso de cualquier excepción o una específica, podemos manejar o capturar la excepción y ejecutar un código específico. Esto nos permitirá continuar la ejecución de nuestro programa incluso si hay una excepción.
#
# Python intenta ejecutar el código en el bloque <code> try </code>. En este caso, si hay alguna excepción generada por el código en el bloque <code> try </code>, será detectada y se ejecutará el bloque de código en el bloque <code> except </code>. Después, se ejecutará el código que viene después del intento, excepto.

# %%
# potential code before try catch

try:
    # code to try to execute
except:
    # code to execute if there is an exception
    
# code that will still execute if there is an exception

# %% [markdown]
# ### Try Except Example

# %% [markdown]
# En este ejemplo estamos tratando de dividir un número dado por el usuario, guardar el resultado en la variable <code> a </code>, y luego nos gustaría imprimir el resultado de la operación. Al tomar la entrada del usuario y dividir un número por ella, hay un par de excepciones que se pueden generar. Por ejemplo, si dividimos entre cero, intente ejecutar el siguiente bloque de código, con <code> b </code> como número, solo se generará una excepción si <code> b </code>, es cero

# %%
a = 1

try:
    b = int(input("Please enter a number to divide a"))
    a = a/b
    print("Success a=",a)
except:
    print("There was an error")
        


### Try Except Specific

# %% [markdown]
# Un <code> Try Except Specific </code> le permite detectar ciertas excepciones y también ejecutar cierto código dependiendo de la excepción. Esto es útil si no desea lidiar con algunas excepciones y la ejecución debería detenerse, también puede ayudarlo a encontrar errores en su código que quizás no conozca y puede ayudarlo a diferenciar las respuestas a diferentes excepciones. En este caso, es posible que el código después del intento no se ejecute según el error.
#
# <b>do not run, just to illustrate</b>

# %%
# potential code before try catch
try:
    # code to try to execute
except (ZeroDivisionError, NameError):
    # code to execute if there is an exception of the given types
    
# code that will execute if there is no exception or a one that we are handling

# %%
# potential code before try catch

try:
    # code to try to execute
except ZeroDivisionError:
    # code to execute if there is a ZeroDivisionError
except NameError:
    # code to execute if there is a NameError
    
# code that will execute if there is no exception or a one that we are handling

# %% [markdown]
# You can also have an empty except at the end to catch an unexpected exception:

# %% [markdown]
# <b>do not run, just to illustrate</b>

# %%
# potential code before try catch

try:
    # code to try to execute
except ZeroDivisionError:
    # code to execute if there is a ZeroDivisionError
except NameError:
    # code to execute if there is a NameError
except:
    # code to execute if ther is any exception
    
# code that will execute if there is no exception or a one that we are handling

# %% [markdown]
# ### Try Except Specific Example

# %% [markdown]
# This is the same example as above, but now we will add differentiated messages depending on the exception letting the user know what is wrong with the input.

# %%
a = 1

try:
    b = int(input("Please enter a number to divide a"))
    a = a/b
    print("Success a=",a)
except ZeroDivisionError:
    print("The number you provided cant divide 1 because it is 0")
except ValueError:
    print("You did not provide a number")
except:
    print("Something went wrong")

# %% [markdown]
# ### Try Except Else and Finally

# %% [markdown]
# <code>else</code> allows one to check if there was no exception when executing the try block. This is useful when we want to execute something only if there were no errors.

# %% [markdown]
# <b>do not run, just to illustrate</b>

# %%
# potential code before try catch

try:
    # code to try to execute
except ZeroDivisionError:
    # code to execute if there is a ZeroDivisionError
except NameError:
    # code to execute if there is a NameError
except:
    # code to execute if ther is any exception
else:
    # code to execute if there is no exception
    
# code that will execute if there is no exception or a one that we are handling

# %% [markdown]
# <code>finally</code> allows us to always execute something even if there is an exception or not. This is usually used to signify the end of the try except.

# %%
# potential code before try catch

try:
    # code to try to execute
except ZeroDivisionError:
    # code to execute if there is a ZeroDivisionError
except NameError:
    # code to execute if there is a NameError
except:
    # code to execute if ther is any exception
else:
    # code to execute if there is no exception
finally:
    # code to execute at the end of the try except no matter what
    
# code that will execute if there is no exception or a one that we are handling

# %% [markdown]
# ### Try Except Else and Finally Example

# %% [markdown]
# You might have noticed that even if there is an error the value of a is always printed. Lets use the else and print the value of a only if there is no error.

# %%
a = 1

try:
    b = int(input("Please enter a number to divide a"))
    a = a/b
except ZeroDivisionError:
    print("The number you provided cant divide 1 because it is 0")
except ValueError:
    print("You did not provide a number")
except:
    print("Something went wrong")
else:
    print("success a=",a)

# %% [markdown]
# Now lets let the user know that we are done processing their answer. Using the <code>finally</code> lets add a print.

# %%
a = 1

try:
    b = int(input("Please enter a number to divide a"))
    a = a/b
except ZeroDivisionError:
    print("The number you provided cant divide 1 because it is 0")
except ValueError:
    print("You did not provide a number")
except:
    print("Something went wrong")
else:
    print("success a=",a)
finally:
    print("Processing Complete")
